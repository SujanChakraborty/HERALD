# %%
# %run benchmark_gdem_added.py
# Out:
# Device: cpu | datasets=['roman-empire', 'amazon-ratings', 'chameleon', 'squirrel', 'flickr', 'reddit', 'ogbn-arxiv'] | condensers=['bonsai', 'herald', 'random', 'herding', 'gdem'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: roman-empire
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   [Full baseline]
#     full/GCN: 41.85±0.20
#     full/GAT: 44.50±1.06
#     full/GIN: 38.20±0.29
#     full/H2GCN: 76.86±0.19
#
#   Condenser=bonsai  frac=1e-05
# ...
# Eval KNN: 100%|################################################################| 12690/12690 [00:01<00:00, 10744.49it/s]
# Eval rKNN: 12690it [00:00, 59289.36it/s]
# ...
# rknn_sorted2budget_select_merged: 100%|########################################| 12676/12676 [00:00<00:00, 70362.64it/s]
#     Condensed in 43.1s  nodes=14789
#     GCN ... 40.30±0.12  (60s)
#     GAT ... 41.88±1.16  (83s)
#     GIN ... 33.70±0.23  (62s)
# ...

# %%
# %run benchmark.py
# Out:
# Device: cpu | datasets=['cora', 'citeseer', 'pubmed', 'roman-empire', 'amazon-ratings', 'chameleon', 'squirrel'] | condensers=['bonsai', 'herald', 'random', 'herding'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: cora
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   [Full baseline]
#     full/GCN: 88.01±0.23
#     full/GAT: 86.35±0.51
#     full/GIN: 85.17±1.33
#     full/H2GCN: 86.27±0.58
#
#   Condenser=bonsai  frac=0.0001
# ...
# Eval KNN: 100%|##################################################################| 1516/1516 [00:00<00:00, 14536.02it/s]
# Eval rKNN: 1516it [00:00, 65921.24it/s]
# ...
# rknn_sorted2budget_select_merged:   7%|###9                                                  | 111/1516 [00:00<?, ?it/s]
#     Condensed in 3.0s  nodes=36
#     GCN ... 45.57±1.02  (21s)
#     GAT ... 47.45±3.70  (27s)
#     GIN ... 48.71±0.61  (21s)
#     H2GCN ... 39.19±0.95  (36s)
#
# ...

# %%
# %run benchmark.py --datasets reddit
# Out:
# Device: cpu | datasets=['reddit'] | condensers=['herald', 'bonsai', 'random', 'herding'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: reddit
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   [Full baseline]
#     full/GCN: 52.48±0.05
#     full/GAT: 51.66±0.73
#     full/GIN: 47.73±1.10
#     full/H2GCN: 50.91±0.21
#
#   Condenser=herald  frac=0.0001
#   [HERALD] h=0.681  α=0.420(proto) β=0.380(boundary) γ=0.200(LID)
# sparsify_enrich: 100%|##########################################################| 49980/49980 [1:48:10<00:00,  7.70it/s]
#   [HERALD] After BFS: 89n / 49980 roots
#   [HERALD] After PPR prune: 59n  (target=1)
#   [HERALD] After rebalance: 64n / 64 target
#     Condensed in 12984.0s  nodes=64
#     GCN ... 43.50±2.22  (1450s)
#     GAT ... 21.40±10.75  (1563s)
#     GIN ... 40.14±3.31  (1306s)
#     H2GCN ... 41.25±0.74  (4519s)
#
#   Condenser=herald  frac=0.005
# ...

# %%
# %run benchmark_arxiv.py --datasets ogbn-arxiv
# Out:
# Device: cpu | datasets=['ogbn-arxiv'] | condensers=['herald', 'bonsai', 'random', 'herding'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: ogbn-arxiv
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   [Full baseline]

# %%
# %run benchmark_pca_v1.py --datasets reddit
# Out:
# Device: cpu | datasets=['reddit'] | condensers=['herald', 'bonsai', 'random', 'herding'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: reddit
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   [Full baseline]
#     full/GCN: 52.48±0.05
#     full/GAT: 51.66±0.73
#     full/GIN: 47.73±1.10
#     full/H2GCN: 50.91±0.21
#
#   Condenser=herald  frac=0.0001
#   [HERALD] h=0.681  α=0.420(proto) β=0.380(boundary) γ=0.200(LID)
# sparsify_enrich: 100%|##########################################################| 49980/49980 [1:27:32<00:00,  9.52it/s]
#   [HERALD] After BFS: 89n / 49980 roots
#   [HERALD] After PPR prune: 59n  (target=1)
#   [HERALD] After rebalance: 64n / 64 target
#   [HERALD] PCA: 500 → 44 features (90.0% variance retained)
#     Condensed in 10671.5s  nodes=64  pca_feats=44
#     [PCA] condensed graph: 500 → 44 features (90.0% variance retained)
# ...

# %%
# %run benchmark_pca_v1_reddit.py --datasets reddit
# Out:
# Device: cpu | datasets=['reddit'] | condensers=['herald', 'bonsai', 'random', 'herding'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: reddit
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   [Full baseline]
#     full/GCN: 52.48±0.05
#     full/GAT: 51.66±0.73
#     full/GIN: 47.73±1.10
#     full/H2GCN: 50.91±0.21
#
#   Condenser=herald  frac=0.0001
#   [HERALD] 500 → 500 features (Bonsai DT count=500, HERALD indices, h=0.68)
#   [HERALD] h=0.681  α=0.420(proto) β=0.380(boundary) γ=0.200(LID)
# sparsify_enrich: 100%|##########################################################| 49980/49980 [1:25:55<00:00,  9.69it/s]
#   [HERALD] After BFS: 85n / 49980 roots
#   [HERALD] After PPR prune: 44n  (target=1)
#   [HERALD] After rebalance: 51n / 51 target
#   [HERALD] PCA: 500 → 36 features (90.0% variance retained)
#     Condensed in 10569.2s  nodes=51  pca_feats=36
# ...

# %%
# %run benchmark_pca_v1_reddit_scalable.py --datasets reddit --condensers herald --skip_full
# Out:
# Device: cpu | datasets=['reddit'] | condensers=['herald'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: reddit
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   Condenser=herald  frac=0.0001
#   [HERALD] 500 → 500 features (Bonsai DT count=500, HERALD indices, h=0.68)
#   [HERALD] h=0.681  α=0.420(proto) β=0.380(boundary) γ=0.200(LID)
# sparsify_enrich:   1%|6                                                             | 507/49980 [00:06<10:29, 78.59it/s]
#   [HERALD] After BFS: 69n / 508 roots
#   [HERALD] After PPR prune: 1n  (target=1)
#   [HERALD] After rebalance: 1n / 1 target
#   [HERALD] PCA: 500 → 1 features (90.0% variance retained)
#     Condensed in 959.5s  nodes=1  pca_feats=1
#     [PCA] condensed graph: 500 → 1 features (90.0% variance retained)
#     GCN ... 7.88±1.38  (2174s)
#     GAT ... 8.52±1.46  (2321s)
#     GIN ... 11.61±7.29  (748s)
# ...
