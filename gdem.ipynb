# %%
# %run benchmark_gdem.py --datasets cora citeseer pubmed roman-empire amazon-ratings --condensers gdem_inline --gnns GCN GAT GIN H2GCN --fracs 0.0001 0.005 0.01 0.03 --seeds 0 1 2 3 4 --nepochs 200 --gdem_epochs 800 --gdem_verbose --skip_full
# Out:
# Device: cpu | datasets=['cora', 'citeseer', 'pubmed', 'roman-empire', 'amazon-ratings'] | condensers=['gdem_inline'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: cora
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   Condenser=gdem_inline  frac=0.0001
#   [GDEM] budget=780B  n_syn=7  (n_train=1516, d=1433)
#   [GDEM] LCC size: 2485/2708
#   [GDEM] Computing eigendecomposition (n_lcc=2485) …
#   [GDEM] Eigendecomposition done. Cached 2485 eigenpairs.
#   [GDEM] eigen_k=7  (K1=7 low, K2=0 high)
#     [GDEM ep 0000]  Le=0.0000 Ld=0.5767  Lo=0.0000  total=0.0000
#     [GDEM ep 0200]  Le=0.0000 Ld=0.2071  Lo=0.0000  total=0.0000
#     [GDEM ep 0400]  Le=0.0000 Ld=0.1310  Lo=0.0000  total=0.0000
#     [GDEM ep 0600]  Le=0.0000 Ld=0.1228  Lo=0.0000  total=0.0000
#     [GDEM ep 0799]  Le=0.0000 Ld=0.1202  Lo=0.0000  total=0.0000
# ...

# %%
# %run benchmark_gdem.py --datasets squirrel chameleon --condensers gdem_inline --gnns GCN GAT GIN H2GCN --fracs 0.0001 0.005 0.01 0.03 --seeds 0 1 2 3 4 --nepochs 200 --gdem_epochs 800 --gdem_verbose --skip_full
# Out:
# Device: cpu | datasets=['squirrel', 'chameleon'] | condensers=['gdem_inline'] | gnns=['GCN', 'GAT', 'GIN', 'H2GCN']
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dataset: squirrel
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   Condenser=gdem_inline  frac=0.0001
#   [GDEM] budget=4433B  n_syn=5  (n_train=2912, d=2089)
#   [GDEM] LCC size: 5201/5201
#   [GDEM] Computing eigendecomposition (n_lcc=5201) …
#   [GDEM] Eigendecomposition done. Cached 2000 eigenpairs.
#   [GDEM] eigen_k=5  (K1=5 low, K2=0 high)
#     [GDEM ep 0000]  Le=0.0000 Ld=0.3895  Lo=0.0000  total=0.0000
#     [GDEM ep 0200]  Le=0.0000 Ld=0.2315  Lo=0.0000  total=0.0000
#     [GDEM ep 0400]  Le=0.0000 Ld=0.1863  Lo=0.0000  total=0.0000
#     [GDEM ep 0600]  Le=0.0000 Ld=0.1643  Lo=0.0000  total=0.0000
#     [GDEM ep 0799]  Le=0.0000 Ld=0.1520  Lo=0.0000  total=0.0000
#   [GDEM] Done in 492.6s  synthetic graph: 5 nodes, 25 edges
# ...
